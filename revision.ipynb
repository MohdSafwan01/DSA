# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSafwan01/DSA/blob/main/revision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
stock_prices = [('Appl',200),('Goog',400),('Msft',100)]

# %%
for item in stock_prices:
  print(item)
# Out:
# ('Appl', 200)
# ('Goog', 400)
# ('Msft', 100)

# %%
for ticker,price in stock_prices:
  print(price+(price*0.1))
# Out:
# 220.0
# 440.0
# 110.0

# %%
marks = [('Safwan',200),('Anas',258),('Imaad',400)]

# %%
def marks_check(marks):

  current_max=0
  top_scorrer= ''

  for scorrer,score in marks:
    if score > current_max:
      current_max = score
      top_scorrer = scorrer
    else:
      pass

  return (top_scorrer,current_max)

# %%
result = marks_check(marks)

# %%
result
# Out:
# ('Imaad', 400)

# %% [markdown]
# Shuffle

# %%
example = [1,2,3,4,5,6]

# %%
from random import shuffle

# %%
shuffle(example)

# %%
example
# Out:
# [5, 4, 3, 1, 6, 2]

# %%
def shuffle_list(mylist):
  shuffle(mylist)
  return mylist

# %%
mylist = [' ','O',' ']

# %%
shuffle_list(mylist)
# Out:
# [' ', 'O', ' ']

# %%
def player_guess():

   guess=''

   while guess not in ['0','1','2']:
    guess = input("Pick a number: 0, 1 or 2")

   return  int(guess)

# %%
player_guess()
# Out:
# Pick a number: 0, 1 or 20
# 0

# %%
myindex = player_guess()
# Out:
# Pick a number: 0, 1 or 21

# %%
myindex
# Out:
# 1

# %%
def check_guess(mylist,guess):
  if mylist[guess]=='O':
    print("correct")
  else:
    print("wrong guess")
    print(mylist)

# %%
#INITIAL LIST
mylist = [' ','O',' ']

#SHUFFLE LIST
mixedup_list = shuffle_list(mylist)

#USER GUESS
guess = player_guess()

#CHECK GUESS
check_guess(mixedup_list,guess)
# Out:
# Pick a number: 0, 1 or 21
# correct

# %% [markdown]
# lesser of two
# LESSER OF TWO EVENS: Write a function that returns the lesser of two given numbers if both numbers are even, but returns the greater if one or both numbers are odd

# %%
def lesser_of_two_evens(a,b):
  if a%2==0 and b%2==0:
    return min(a,b)
  else:
    return max(a,b)
  pass

# %%
lesser_of_two_evens(5,7)
# Out:
# 7

# %% [markdown]
# ANIMAL CRACKERS: Write a function takes a two-word string and returns True if both words begin with same letter

# %%
def animal_cracker(text):
  word = text.split()
  if word[0][0]==word[1][0]:
    return True
  else:
    return False

# %%
animal_cracker("Levelheaded Llamma")
# Out:
# True

# %%
animal_cracker("crazy kangaroo")
# Out:
# False

# %% [markdown]
# MAKES TWENTY: Given two integers, return True if the sum of the integers is 20 or if one of the integers is 20. If not, return False

# %%
def makes_twenty(n1,n2):
  if n1 == 20 or n2 == 20:
    return True
  elif n1+n2==20:
    return True
  else:
    return False

# %%
makes_twenty(20,3)
# Out:
# True

# %% [markdown]
# OLD MACDONALD: Write a function that capitalizes the first and fourth letters of a name
#
# old_macdonald('macdonald') --> MacDonald

# %%
def old_macdonald(name):
    final_name = name[0].upper() + name[1:3] + name[3].upper() + name[4:]
    return final_name

# %%
old_macdonald("macdonald")
# Out:
# 'MacDonald'

# %%
gvname= 'safwan'

# %%
name.upper()
# Out:
# 'SAFWAN'

# %%
name[4:]
# Out:
# 'an'
