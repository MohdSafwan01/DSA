# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSafwan01/DSA/blob/main/Basic_Maths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem Statement: Given an integer N, return the number of digits in N.

# %%
#brute force approach
def count_digits(n):
 cnt = 0
 while n>0:
  cnt=cnt+1
  n=n//10

 return cnt

# %%
count_digits(1234)
# Out:
# 4

# %%
#optimal approach
import math
def count_digits(n):
  #log10 of any number appears to be a no. of digit lesser than it has
  #example: log10(2345) = 3.37014284
  # so adding 1 to it and returning it as integer will give us the no. of digit

  cnt=int(math.log10(n)+1)
  return cnt

# %%
count_digits(345567)
# Out:
# 6

# %% [markdown]
# Reverse Digits of A Number

# %%
def reverse(n):
    reverse_no=0
    while n>0:
        last_digit=(n%10)
        reverse_no=(reverse_no*10)+last_digit


        n=n//10
    return reverse_no

# %%
reverse(45890)
# Out:
# 9854

# %%
def reverse(x):
        s=str(x)
        if s[0]=='-':
          rev='-'+s[:0:-1]
        else:
          rev=s[::-1]




        return int(rev)

# %%
reverse(9000000000)
# Out:
# 9
